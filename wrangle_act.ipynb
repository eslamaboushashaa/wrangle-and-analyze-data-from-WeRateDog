# %% [markdown]
# # Gathering data

# %%
#import pandas to read data 
import pandas as pd 
import os
#import requests to get data from link
import requests
#import json to read and use data in json file
import json
#import matplotlib to create graph
from matplotlib import pyplot as plt 
#read_archive-enganced.csv_file_by_pandas
read_arch = pd.read_csv("/run/media/eslam/36AE1665AE161DC5/my_githup/wrangle-and-analyze-from-WeRateDogs/twitter-archive-enhanced.csv")

# %%
#i_install_image_prediction_progrmmatly_by_reqests_model
# this link contain data
url = "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
#to get data from link use get function in requests libaray
data_images= requests.get(url)

# %%
#i will seprate the name of file form link and save it in new variable
file_name =url.split("/")[-1]
file_name
# Out:
# 'image-predictions.tsv'

# %%
#this_step_to_creat_new_folder and save data if file don't founed but the file it founded he save in data 
if not  os.path.isfile(file_name):   
    #to open the folder 
    with open (file_name,"wb") as file:
        file.write(data_images.content)
#to read data in file tsv 
read_images = pd.read_csv(file_name, sep="\t")
#apper the first 10 ram in data
read_images.head(10)
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5  666050758794694657  https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6  666051853826850816  https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7  666055525042405380  https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8  666057090499244032  https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9  666058600524156928  https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
# 5        1    Bernese_mountain_dog  0.651137    True    English_springer
# 6        1              box_turtle  0.933012   False          mud_turtle
# 7        1                    chow  0.692517    True     Tibetan_mastiff
# 8        1           shopping_cart  0.962465   False     shopping_basket
# 9        1        miniature_poodle  0.201493    True            komondor
#
#     p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 0  0.156665    True            Shetland_sheepdog  0.061428    True
# 1  0.074192    True          Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True                   bloodhound  0.116197    True
# 3  0.360687    True           miniature_pinscher  0.222752    True
# 4  0.243682    True                     Doberman  0.154629    True
# 5  0.263788    True   Greater_Swiss_Mountain_dog  0.016199    True
# 6  0.045885   False                     terrapin  0.017885   False
# 7  0.058279    True                     fur_coat  0.054449   False
# 8  0.014594   False             golden_retriever  0.007959    True
# 9  0.192305    True  soft-coated_wheaten_terrier  0.082086    True

# %%
#df_tweets this list to store the new data  
df_tweets =[]
#to open the file and close it but this file can edit in beacause the mode is read only
with open("/run/media/eslam/36AE1665AE161DC5/my_githup/wrangle-and-analyze-from-WeRateDogs/tweet-json.txt",mode="r") as folder:
# here i want read the file line by line so that i use loop
    for line in folder:
    #to read string in dictionary line by line in josn
        tweet = json.loads(line)
        tweet_id = tweet["id"]
        retweet_count= tweet["retweet_count"]
        fav_count = tweet["favorite_count"]
        df_tweets.append({"tweet_id":tweet_id,
                          "retweet_count":retweet_count,
                          "favorite_count":fav_count})
#read the file json data
read_tweets = pd.DataFrame(df_tweets,columns=["tweet_id","retweet_count","favorite_count"])
read_tweets
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           8853           39467
# 1     892177421306343426           6514           33819
# 2     891815181378084864           4328           25461
# 3     891689557279858688           8964           42908
# 4     891327558926688256           9774           41048
# ...                  ...            ...             ...
# 2349  666049248165822465             41             111
# 2350  666044226329800704            147             311
# 2351  666033412701032449             47             128
# 2352  666029285002620928             48             132
# 2353  666020888022790149            532            2535
#
# [2354 rows x 3 columns]

# %% [markdown]
# # Assesing data

# %%
#do show all columns
pd.set_option("display.max_columns", None)

# %%
read_arch
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator      name doggo floofer pupper puppo
# 0                     10   Phineas  None    None   None  None
# 1                     10     Tilly  None    None   None  None
# 2                     10    Archie  None    None   None  None
# 3                     10     Darla  None    None   None  None
# 4                     10  Franklin  None    None   None  None
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10      None  None    None   None  None
# 2352                  10         a  None    None   None  None
# 2353                  10         a  None    None   None  None
# 2354                  10         a  None    None   None  None
# 2355                  10      None  None    None   None  None
#
# [2356 rows x 17 columns]

# %%
#i want some informition in read_arch data like type columns and what contint in columuns 
read_arch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
#  13  doggo                       2356 non-null   object
#  14  floofer                     2356 non-null   object
#  15  pupper                      2356 non-null   object
#  16  puppo                       2356 non-null   object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
#to know every character in columns and how many apper in coulmns
read_arch["name"].value_counts()
# Out:
# None        745
# a            55
# Charlie      12
# Lucy         11
# Cooper       11
#            ...
# Schnozz       1
# Binky         1
# Ebby          1
# all           1
# Cilantro      1
# Name: name, Length: 957, dtype: int64

# %%
#to know all character in columns
read_arch.name.unique()
# Out:
# array(['Phineas', 'Tilly', 'Archie', 'Darla', 'Franklin', 'None', 'Jax',
#        'Zoey', 'Cassie', 'Koda', 'Bruno', 'Ted', 'Stuart', 'Oliver',
#        'Jim', 'Zeke', 'Ralphus', 'Canela', 'Gerald', 'Jeffrey', 'such',
#        'Maya', 'Mingus', 'Derek', 'Roscoe', 'Waffles', 'Jimbo', 'Maisey',
#        'Lilly', 'Earl', 'Lola', 'Kevin', 'Yogi', 'Noah', 'Bella',
#        'Grizzwald', 'Rusty', 'Gus', 'Stanley', 'Alfy', 'Koko', 'Rey',
#        'Gary', 'a', 'Elliot', 'Louis', 'Jesse', 'Romeo', 'Bailey',
#        'Duddles', 'Jack', 'Emmy', 'Steven', 'Beau', 'Snoopy', 'Shadow',
#        'Terrance', 'Aja', 'Penny', 'Dante', 'Nelly', 'Ginger', 'Benedict',
#        'Venti', 'Goose', 'Nugget', 'Cash', 'Coco', 'Jed', 'Sebastian',
#        'Walter', 'Sierra', 'Monkey', 'Harry', 'Kody', 'Lassie', 'Rover',
#        'Napolean', 'Dawn', 'Boomer', 'Cody', 'Rumble', 'Clifford',
#        'quite', 'Dewey', 'Scout', 'Gizmo', 'Cooper', 'Harold', 'Shikha',
#        'Jamesy', 'Lili', 'Sammy', 'Meatball', 'Paisley', 'Albus',
#        'Neptune', 'Quinn', 'Belle', 'Zooey', 'Dave', 'Jersey', 'Hobbes',
#        'Burt', 'Lorenzo', 'Carl', 'Jordy', 'Milky', 'Trooper', 'Winston',
#        'Sophie', 'Wyatt', 'Rosie', 'Thor', 'Oscar', 'Luna', 'Callie',
#        'Cermet', 'George', 'Marlee', 'Arya', 'Einstein', 'Alice',
#        'Rumpole', 'Benny', 'Aspen', 'Jarod', 'Wiggles', 'General',
#        'Sailor', 'Astrid', 'Iggy', 'Snoop', 'Kyle', 'Leo', 'Riley',
#        'Gidget', 'Noosh', 'Odin', 'Jerry', 'Charlie', 'Georgie', 'Rontu',
#        'Cannon', 'Furzey', 'Daisy', 'Tuck', 'Barney', 'Vixen', 'Jarvis',
#        'Mimosa', 'Pickles', 'Bungalo', 'Brady', 'Margo', 'Sadie', 'Hank',
#        'Tycho', 'Stephan', 'Indie', 'Winnie', 'Bentley', 'Ken', 'Max',
#        'Maddie', 'Pipsy', 'Monty', 'Sojourner', 'Odie', 'Arlo', 'Sunny',
#        'Vincent', 'Lucy', 'Clark', 'Mookie', 'Meera', 'Buddy', 'Ava',
#        'Rory', 'Eli', 'Ash', 'Tucker', 'Tobi', 'Chester', 'Wilson',
#        'Sunshine', 'Lipton', 'Gabby', 'Bronte', 'Poppy', 'Rhino',
#        'Willow', 'not', 'Orion', 'Eevee', 'Smiley', 'Logan', 'Moreton',
#        'Klein', 'Miguel', 'Emanuel', 'Kuyu', 'Dutch', 'Pete', 'Scooter',
#        'Reggie', 'Kyro', 'Samson', 'Loki', 'Mia', 'Malcolm', 'Dexter',
#        'Alfie', 'Fiona', 'one', 'Mutt', 'Bear', 'Doobert', 'Beebop',
#        'Alexander', 'Sailer', 'Brutus', 'Kona', 'Boots', 'Ralphie',
#        'Phil', 'Cupid', 'Pawnd', 'Pilot', 'Ike', 'Mo', 'Toby', 'Sweet',
#        'Pablo', 'Nala', 'Balto', 'Crawford', 'Gabe', 'Mattie', 'Jimison',
#        'Hercules', 'Duchess', 'Harlso', 'Sampson', 'Sundance', 'Luca',
#        'Flash', 'Finn', 'Peaches', 'Howie', 'Jazzy', 'Anna', 'Bo',
#        'Seamus', 'Wafer', 'Chelsea', 'Tom', 'Moose', 'Florence', 'Autumn',
#        'Dido', 'Eugene', 'Herschel', 'Strudel', 'Tebow', 'Chloe', 'Betty',
#        'Timber', 'Binky', 'Dudley', 'Comet', 'Larry', 'Levi', 'Akumi',
#        'Titan', 'Olivia', 'Alf', 'Oshie', 'Bruce', 'Chubbs', 'Sky',
#        'Atlas', 'Eleanor', 'Layla', 'Rocky', 'Baron', 'Tyr', 'Bauer',
#        'Swagger', 'Brandi', 'Mary', 'Moe', 'Halo', 'Augie', 'Craig',
#        'Sam', 'Hunter', 'Pavlov', 'Maximus', 'Wallace', 'Ito', 'Milo',
#        'Ollie', 'Cali', 'Lennon', 'incredibly', 'Major', 'Duke',
#        'Reginald', 'Sansa', 'Shooter', 'Django', 'Diogi', 'Sonny',
#        'Philbert', 'Marley', 'Severus', 'Ronnie', 'Anakin', 'Bones',
#        'Mauve', 'Chef', 'Doc', 'Sobe', 'Longfellow', 'Mister', 'Iroh',
#        'Baloo', 'Stubert', 'Paull', 'Timison', 'Davey', 'Pancake',
#        'Tyrone', 'Snicku', 'Ruby', 'Brody', 'Rizzy', 'Mack', 'Butter',
#        'Nimbus', 'Laika', 'Dobby', 'Juno', 'Maude', 'Lily', 'Newt',
#        'Benji', 'Nida', 'Robin', 'Monster', 'BeBe', 'Remus', 'Mabel',
#        'Misty', 'Happy', 'Mosby', 'Maggie', 'Leela', 'Ralphy', 'Brownie',
#        'Meyer', 'Stella', 'mad', 'Frank', 'Tonks', 'Lincoln', 'Oakley',
#        'Dale', 'Rizzo', 'Arnie', 'Pinot', 'Dallas', 'Hero', 'Frankie',
#        'Stormy', 'Mairi', 'Loomis', 'Godi', 'Kenny', 'Deacon', 'Timmy',
#        'Harper', 'Chipson', 'Combo', 'Dash', 'Bell', 'Hurley', 'Jay',
#        'Mya', 'Strider', 'an', 'Wesley', 'Solomon', 'Huck', 'very', 'O',
#        'Blue', 'Finley', 'Sprinkles', 'Heinrich', 'Shakespeare', 'Fizz',
#        'Chip', 'Grey', 'Roosevelt', 'Gromit', 'Willem', 'Dakota', 'Dixie',
#        'Al', 'Jackson', 'just', 'Carbon', 'DonDon', 'Kirby', 'Lou',
#        'Nollie', 'Chevy', 'Tito', 'Louie', 'Rupert', 'Rufus', 'Brudge',
#        'Shadoe', 'Colby', 'Angel', 'Brat', 'Tove', 'my', 'Aubie', 'Kota',
#        'Eve', 'Glenn', 'Shelby', 'Sephie', 'Bonaparte', 'Albert',
#        'Wishes', 'Rose', 'Theo', 'Rocco', 'Fido', 'Emma', 'Spencer',
#        'Lilli', 'Boston', 'Brandonald', 'Corey', 'Leonard', 'Chompsky',
#        'Beckham', 'Devón', 'Gert', 'Watson', 'Rubio', 'Keith', 'Dex',
#        'Carly', 'Ace', 'Tayzie', 'Grizzie', 'Fred', 'Gilbert', 'Zoe',
#        'Stewie', 'Calvin', 'Lilah', 'Spanky', 'Jameson', 'Piper',
#        'Atticus', 'Blu', 'Dietrich', 'Divine', 'Tripp', 'his', 'Cora',
#        'Huxley', 'Keurig', 'Bookstore', 'Linus', 'Abby', 'Shaggy',
#        'Shiloh', 'Gustav', 'Arlen', 'Percy', 'Lenox', 'Sugar', 'Harvey',
#        'Blanket', 'actually', 'Geno', 'Stark', 'Beya', 'Kilo', 'Kayla',
#        'Maxaroni', 'Doug', 'Edmund', 'Aqua', 'Theodore', 'Chase',
#        'getting', 'Rorie', 'Simba', 'Charles', 'Bayley', 'Axel',
#        'Storkson', 'Remy', 'Chadrick', 'Kellogg', 'Buckley', 'Livvie',
#        'Terry', 'Hermione', 'Ralpher', 'Aldrick', 'this', 'unacceptable',
#        'Rooney', 'Crystal', 'Ziva', 'Stefan', 'Pupcasso', 'Puff',
#        'Flurpson', 'Coleman', 'Enchilada', 'Raymond', 'all', 'Rueben',
#        'Cilantro', 'Karll', 'Sprout', 'Blitz', 'Bloop', 'Lillie',
#        'Ashleigh', 'Kreggory', 'Sarge', 'Luther', 'Ivar', 'Jangle',
#        'Schnitzel', 'Panda', 'Berkeley', 'Ralphé', 'Charleson', 'Clyde',
#        'Harnold', 'Sid', 'Pippa', 'Otis', 'Carper', 'Bowie',
#        'Alexanderson', 'Suki', 'Barclay', 'Skittle', 'Ebby', 'Flávio',
#        'Smokey', 'Link', 'Jennifur', 'Ozzy', 'Bluebert', 'Stephanus',
#        'Bubbles', 'old', 'Zeus', 'Bertson', 'Nico', 'Michelangelope',
#        'Siba', 'Calbert', 'Curtis', 'Travis', 'Thumas', 'Kanu', 'Lance',
#        'Opie', 'Kane', 'Olive', 'Chuckles', 'Staniel', 'Sora', 'Beemo',
#        'Gunner', 'infuriating', 'Lacy', 'Tater', 'Olaf', 'Cecil', 'Vince',
#        'Karma', 'Billy', 'Walker', 'Rodney', 'Klevin', 'Malikai',
#        'Bobble', 'River', 'Jebberson', 'Remington', 'Farfle', 'Jiminus',
#        'Clarkus', 'Finnegus', 'Cupcake', 'Kathmandu', 'Ellie', 'Katie',
#        'Kara', 'Adele', 'Zara', 'Ambrose', 'Jimothy', 'Bode', 'Terrenth',
#        'Reese', 'Chesterson', 'Lucia', 'Bisquick', 'Ralphson', 'Socks',
#        'Rambo', 'Rudy', 'Fiji', 'Rilo', 'Bilbo', 'Coopson', 'Yoda',
#        'Millie', 'Chet', 'Crouton', 'Daniel', 'Kaia', 'Murphy', 'Dotsy',
#        'Eazy', 'Coops', 'Fillup', 'Miley', 'Charl', 'Reagan', 'Yukon',
#        'CeCe', 'Cuddles', 'Claude', 'Jessiga', 'Carter', 'Ole', 'Pherb',
#        'Blipson', 'Reptar', 'Trevith', 'Berb', 'Bob', 'Colin', 'Brian',
#        'Oliviér', 'Grady', 'Kobe', 'Freddery', 'Bodie', 'Dunkin', 'Wally',
#        'Tupawc', 'Amber', 'Edgar', 'Teddy', 'Kingsley', 'Brockly',
#        'Richie', 'Molly', 'Vinscent', 'Cedrick', 'Hazel', 'Lolo', 'Eriq',
#        'Phred', 'the', 'Oddie', 'Maxwell', 'Geoff', 'Covach', 'Durg',
#        'Fynn', 'Ricky', 'Herald', 'Lucky', 'Ferg', 'Trip', 'Clarence',
#        'Hamrick', 'Brad', 'Pubert', 'Frönq', 'Derby', 'Lizzie', 'Ember',
#        'Blakely', 'Opal', 'Marq', 'Kramer', 'Barry', 'Gordon', 'Baxter',
#        'Mona', 'Horace', 'Crimson', 'Birf', 'Hammond', 'Lorelei', 'Marty',
#        'Brooks', 'Petrick', 'Hubertson', 'Gerbald', 'Oreo', 'Bruiser',
#        'Perry', 'Bobby', 'Jeph', 'Obi', 'Tino', 'Kulet', 'Sweets', 'Lupe',
#        'Tiger', 'Jiminy', 'Griffin', 'Banjo', 'Brandy', 'Lulu', 'Darrel',
#        'Taco', 'Joey', 'Patrick', 'Kreg', 'Todo', 'Tess', 'Ulysses',
#        'Toffee', 'Apollo', 'Asher', 'Glacier', 'Chuck', 'Champ', 'Ozzie',
#        'Griswold', 'Cheesy', 'Moofasa', 'Hector', 'Goliath', 'Kawhi',
#        'by', 'Emmie', 'Penelope', 'Willie', 'Rinna', 'Mike', 'William',
#        'Dwight', 'Evy', 'officially', 'Rascal', 'Linda', 'Tug', 'Tango',
#        'Grizz', 'Jerome', 'Crumpet', 'Jessifer', 'Izzy', 'Ralph', 'Sandy',
#        'Humphrey', 'Tassy', 'Juckson', 'Chuq', 'Tyrus', 'Karl',
#        'Godzilla', 'Vinnie', 'Kenneth', 'Herm', 'Bert', 'Striker',
#        'Donny', 'Pepper', 'Bernie', 'Buddah', 'Lenny', 'Arnold', 'Zuzu',
#        'Mollie', 'Laela', 'Tedders', 'Superpup', 'Rufio', 'Jeb', 'Rodman',
#        'Jonah', 'Chesney', 'life', 'Henry', 'Bobbay', 'Mitch', 'Kaiya',
#        'Acro', 'Aiden', 'Obie', 'Dot', 'Shnuggles', 'Kendall', 'Jeffri',
#        'Steve', 'Mac', 'Fletcher', 'Kenzie', 'Pumpkin', 'Schnozz',
#        'Gustaf', 'Cheryl', 'Ed', 'Leonidas', 'Norman', 'Caryl', 'Scott',
#        'Taz', 'Darby', 'Jackie', 'light', 'Jazz', 'Franq', 'Pippin',
#        'Rolf', 'Snickers', 'Ridley', 'Cal', 'Bradley', 'Bubba', 'Tuco',
#        'Patch', 'Mojo', 'Batdog', 'Dylan', 'space', 'Mark', 'JD',
#        'Alejandro', 'Scruffers', 'Pip', 'Julius', 'Tanner', 'Sparky',
#        'Anthony', 'Holly', 'Jett', 'Amy', 'Sage', 'Andy', 'Mason',
#        'Trigger', 'Antony', 'Creg', 'Traviss', 'Gin', 'Jeffrie', 'Danny',
#        'Ester', 'Pluto', 'Bloo', 'Edd', 'Willy', 'Herb', 'Damon',
#        'Peanut', 'Nigel', 'Butters', 'Sandra', 'Fabio', 'Randall', 'Liam',
#        'Tommy', 'Ben', 'Raphael', 'Julio', 'Andru', 'Kloey', 'Shawwn',
#        'Skye', 'Kollin', 'Ronduh', 'Billl', 'Saydee', 'Dug', 'Tessa',
#        'Sully', 'Kirk', 'Ralf', 'Clarq', 'Jaspers', 'Samsom', 'Harrison',
#        'Chaz', 'Jeremy', 'Jaycob', 'Lambeau', 'Ruffles', 'Amélie', 'Bobb',
#        'Banditt', 'Kevon', 'Winifred', 'Hanz', 'Churlie', 'Zeek',
#        'Timofy', 'Maks', 'Jomathan', 'Kallie', 'Marvin', 'Spark',
#        'Gòrdón', 'Jo', 'DayZ', 'Jareld', 'Torque', 'Ron', 'Skittles',
#        'Cleopatricia', 'Erik', 'Stu', 'Tedrick', 'Filup', 'Kial',
#        'Naphaniel', 'Dook', 'Hall', 'Philippe', 'Biden', 'Fwed',
#        'Genevieve', 'Joshwa', 'Bradlay', 'Clybe', 'Keet', 'Carll',
#        'Jockson', 'Josep', 'Lugan', 'Christoper'], dtype=object)

# %%
read_arch["retweeted_status_id"].value_counts()
# Out:
# 7.757333e+17    1
# 7.507196e+17    1
# 6.742918e+17    1
# 6.833919e+17    1
# 8.269587e+17    1
#                ..
# 7.848260e+17    1
# 7.806013e+17    1
# 8.305833e+17    1
# 7.047611e+17    1
# 7.331095e+17    1
# Name: retweeted_status_id, Length: 181, dtype: int64

# %%
read_arch["doggo"].value_counts()
# Out:
# None     2259
# doggo      97
# Name: doggo, dtype: int64

# %%
read_arch["floofer"].value_counts()
# Out:
# None       2346
# floofer      10
# Name: floofer, dtype: int64

# %%
read_arch["pupper"].value_counts()
# Out:
# None      2099
# pupper     257
# Name: pupper, dtype: int64

# %%
read_arch["puppo"].value_counts()
# Out:
# None     2326
# puppo      30
# Name: puppo, dtype: int64

# %%
read_arch["rating_numerator"].value_counts()
# Out:
# 12      558
# 11      464
# 10      461
# 13      351
# 9       158
# 8       102
# 7        55
# 14       54
# 5        37
# 6        32
# 3        19
# 4        17
# 1         9
# 2         9
# 420       2
# 0         2
# 15        2
# 75        2
# 80        1
# 20        1
# 24        1
# 26        1
# 44        1
# 50        1
# 60        1
# 165       1
# 84        1
# 88        1
# 144       1
# 182       1
# 143       1
# 666       1
# 960       1
# 1776      1
# 17        1
# 27        1
# 45        1
# 99        1
# 121       1
# 204       1
# Name: rating_numerator, dtype: int64

# %%
read_arch["rating_denominator"].value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
#to apper 15 ram but randomly
read_images.sample(15)
# Out:
#                 tweet_id                                          jpg_url  \
# 1484  781524693396357120  https://pbs.twimg.com/media/CtiIj0AWcAEBDvw.jpg
# 1790  830097400375152640  https://pbs.twimg.com/media/C4UZLZLWYAA0dcs.jpg
# 1321  756303284449767430  https://pbs.twimg.com/media/Cn7tyyZWYAAPlAY.jpg
# 1113  724405726123311104  https://pbs.twimg.com/media/Cg2bKLAWwAA0WEm.jpg
# 145   668625577880875008  https://pbs.twimg.com/media/CUdvambWoAA007z.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 1741  822610361945911296  https://pbs.twimg.com/media/C2p_wQyXEAELtvS.jpg
# 639   681297372102656000  https://pbs.twimg.com/media/CXR0WJ_W8AMd_O8.jpg
# 2040  885167619883638784  https://pbs.twimg.com/media/DEi_N9qXYAAgEEw.jpg
# 226   670361874861563904  https://pbs.twimg.com/media/CU2akCQWsAIbaOV.jpg
# 662   682638830361513985  https://pbs.twimg.com/media/CXk4W0qWYAMEMEs.jpg
# 1821  834574053763584002  https://pbs.twimg.com/media/C5UAqgyXAAAbMWH.jpg
# 156   668826086256599040  https://pbs.twimg.com/media/CUglxbFXAAA5O0d.jpg
# 930   703041949650034688  https://pbs.twimg.com/media/CcG07BYW0AErrC9.jpg
# 913   700864154249383937  https://pbs.twimg.com/media/Cbn4OqKWwAADGWt.jpg
#
#       img_num                p1   p1_conf  p1_dog                        p2  \
# 1484        1       tennis_ball  0.994712   False  Chesapeake_Bay_retriever
# 1790        4        toy_poodle  0.442713    True                Pomeranian
# 1321        1  golden_retriever  0.981652    True            cocker_spaniel
# 1113        1  golden_retriever  0.240695    True            cocker_spaniel
# 145         1                ox  0.071536   False               groenendael
# 2073        1         Chihuahua  0.323581    True                  Pekinese
# 1741        1    cocker_spaniel  0.664487    True           Norfolk_terrier
# 639         1             Lhasa  0.482401    True                  Shih-Tzu
# 2040        4          malamute  0.812482    True            Siberian_husky
# 226         1          platypus  0.974075   False        spotted_salamander
# 662         1  English_springer  0.440781    True                  Cardigan
# 1821        1     toilet_tissue  0.262936   False          golden_retriever
# 156         1          malinois  0.640185    True             Irish_terrier
# 930         1      hippopotamus  0.581403   False                   doormat
# 913         1            kuvasz  0.805857    True            Great_Pyrenees
#
#        p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 1484  0.003523    True   Labrador_retriever  0.000921    True
# 1790  0.142073    True             Pekinese  0.125745    True
# 1321  0.006790    True   Labrador_retriever  0.004325    True
# 1113  0.202444    True          feather_boa  0.159348   False
# 145   0.054455    True               Angora  0.045028   False
# 2073  0.090647    True             papillon  0.068957    True
# 1741  0.075089    True      Norwich_terrier  0.059644    True
# 639   0.113672    True           Pomeranian  0.096229    True
# 2040  0.071712    True           Eskimo_dog  0.055770    True
# 226   0.011068   False                bison  0.003897   False
# 662   0.411182    True        Border_collie  0.022412    True
# 1821  0.226564    True              bathtub  0.078879   False
# 156   0.153700    True  Rhodesian_ridgeback  0.068457    True
# 930   0.152445   False             sea_lion  0.026364   False
# 913   0.187272    True              Samoyed  0.003491    True

# %%
read_images.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
read_tweets
# Out:
#                 tweet_id  retweet_count  favorite_count
# 0     892420643555336193           8853           39467
# 1     892177421306343426           6514           33819
# 2     891815181378084864           4328           25461
# 3     891689557279858688           8964           42908
# 4     891327558926688256           9774           41048
# ...                  ...            ...             ...
# 2349  666049248165822465             41             111
# 2350  666044226329800704            147             311
# 2351  666033412701032449             47             128
# 2352  666029285002620928             48             132
# 2353  666020888022790149            532            2535
#
# [2354 rows x 3 columns]

# %%
read_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2354 non-null   int64
#  1   retweet_count   2354 non-null   int64
#  2   favorite_count  2354 non-null   int64
# dtypes: int64(3)
# memory usage: 55.3 KB

# %%
#to know common order in static like mean and standar disation and minmam maximam
read_tweets["retweet_count"].describe()
# Out:
# count     2354.000000
# mean      3164.797366
# std       5284.770364
# min          0.000000
# 25%        624.500000
# 50%       1473.500000
# 75%       3652.000000
# max      79515.000000
# Name: retweet_count, dtype: float64

# %%
#to apper the raw which contain miss or have None in data in column's retweet_count
None_in_retweet_count=[read_tweets["retweet_count"].isnull()]==True

# %%
None_in_retweet_count
# Out:
# False

# %%
read_tweets["favorite_count"].value_counts()
# Out:
# 0        179
# 610        3
# 345        3
# 2918       3
# 1691       3
#         ...
# 33345      1
# 814        1
# 23108      1
# 2630       1
# 8143       1
# Name: favorite_count, Length: 2007, dtype: int64

# %% [markdown]
# # Qulaity issues

# %% [markdown]
# 1- Data in in_reply_to_status_id and in_reply_to_user_id aren't founed
#
# 2- retweeted_status_timestamp is object but it should datetime
#
# 3- most rating_numerator column's is over rating
#
# 4- fufo , doggo , floofer , purrer this data in this columns not complet
#
# 5- the image data is 2075 some data missing
#
# 6- conver timestamp from object to data time
#
# 7- Data in retweeted_status_id and retweeted_status_user_id and retweeted_status_timestamp aren't founed
#
# 8- we can remove colums in_reply_to_status_id and in_reply_to_user_id because we don't import it
#
# 9- i find the wrong name in name columns
#
# 10- use in seprate in read_images is "_" in p1 ,p2 and p3 columns

# %% [markdown]
# # Tidiness issues

# %% [markdown]
# 1-in general should tweet_data and data_arch table be one table.
#
# 2-the coulmns doggo, floofer, pupper, puppor should be on variable in one coulmns.

# %% [markdown]
# # cleaning

# %%
read_arch_new = read_arch.copy()
read_images_new = read_images.copy()
read_tweets_new = read_tweets.copy()

# %% [markdown]
# # define

# %% [markdown]
# replace the "_" in p1, p2 and p3

# %% [markdown]
# # code

# %%
# replace under scol "_" to space " "
read_images_new["p1"] = read_images_new.p1.str.replace("_"," ")
read_images_new["p2"] = read_images_new.p2.str.replace("_"," ")
read_images_new["p3"] = read_images_new.p3.str.replace("_"," ")

# %%
read_images_new.head(10)
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5  666050758794694657  https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6  666051853826850816  https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7  666055525042405380  https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8  666057090499244032  https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9  666058600524156928  https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh springer spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature pinscher
# 2        1         German shepherd  0.596461    True            malinois
# 3        1     Rhodesian ridgeback  0.408143    True             redbone
# 4        1      miniature pinscher  0.560311    True          Rottweiler
# 5        1    Bernese mountain dog  0.651137    True    English springer
# 6        1              box turtle  0.933012   False          mud turtle
# 7        1                    chow  0.692517    True     Tibetan mastiff
# 8        1           shopping cart  0.962465   False     shopping basket
# 9        1        miniature poodle  0.201493    True            komondor
#
#     p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 0  0.156665    True            Shetland sheepdog  0.061428    True
# 1  0.074192    True          Rhodesian ridgeback  0.072010    True
# 2  0.138584    True                   bloodhound  0.116197    True
# 3  0.360687    True           miniature pinscher  0.222752    True
# 4  0.243682    True                     Doberman  0.154629    True
# 5  0.263788    True   Greater Swiss Mountain dog  0.016199    True
# 6  0.045885   False                     terrapin  0.017885   False
# 7  0.058279    True                     fur coat  0.054449   False
# 8  0.014594   False             golden retriever  0.007959    True
# 9  0.192305    True  soft-coated wheaten terrier  0.082086    True

# %% [markdown]
# # define

# %% [markdown]
# ## code

# %%
read_arch_new
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# ...                  ...                    ...                  ...
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 0     2017-08-01 16:23:56 +0000
# 1     2017-08-01 00:17:27 +0000
# 2     2017-07-31 00:18:03 +0000
# 3     2017-07-30 15:58:51 +0000
# 4     2017-07-29 16:00:24 +0000
# ...                         ...
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator      name doggo floofer pupper puppo
# 0                     10   Phineas  None    None   None  None
# 1                     10     Tilly  None    None   None  None
# 2                     10    Archie  None    None   None  None
# 3                     10     Darla  None    None   None  None
# 4                     10  Franklin  None    None   None  None
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10      None  None    None   None  None
# 2352                  10         a  None    None   None  None
# 2353                  10         a  None    None   None  None
# 2354                  10         a  None    None   None  None
# 2355                  10      None  None    None   None  None
#
# [2356 rows x 17 columns]

# %% [markdown]
# ## define

# %% [markdown]
# replace  all mistake name to None

# %% [markdown]
# ## code

# %%
#first we should display the mistake name 
read_arch_new[(read_arch_new["name"].str.islower()==True)]["name"].unique()
# Out:
# array(['such', 'a', 'quite', 'not', 'one', 'incredibly', 'mad', 'an',
#        'very', 'just', 'my', 'his', 'actually', 'getting', 'this',
#        'unacceptable', 'all', 'old', 'infuriating', 'the', 'by',
#        'officially', 'life', 'light', 'space'], dtype=object)

# %%
# i make all mistake name in list
mistake_name=['such', 'a', 'quite', 'not', 'one', 'incredibly', 'mad', 'an',
       'very', 'just', 'my', 'his', 'actually', 'getting', 'this',
       'unacceptable', 'all', 'old', 'infuriating', 'the', 'by',
       'officially', 'life', 'light', 'space']

# %%
#we will replace the mistake name to None 

#this loop to read name by name in list
for name in mistake_name:
    read_arch_new["name"].replace(name,"None",inplace=True)

# %%
read_arch_new["name"].value_counts()
# Out:
# None       854
# Charlie     12
# Lucy        11
# Cooper      11
# Oliver      11
#           ...
# Kane         1
# Mojo         1
# Apollo       1
# Kanu         1
# Arlen        1
# Name: name, Length: 932, dtype: int64

# %% [markdown]
# # define
# remove in_reply_to_status_id and in_reply_to_user_id columns in table

# %% [markdown]
# # code

# %%
#remove this columns from read_arch
read_arch_new.drop(["in_reply_to_status_id","in_reply_to_user_id"],axis=1, inplace =True)

# %%
read_arch_new
# Out:
#                 tweet_id                  timestamp  \
# 0     892420643555336193  2017-08-01 16:23:56 +0000
# 1     892177421306343426  2017-08-01 00:17:27 +0000
# 2     891815181378084864  2017-07-31 00:18:03 +0000
# 3     891689557279858688  2017-07-30 15:58:51 +0000
# 4     891327558926688256  2017-07-29 16:00:24 +0000
# ...                  ...                        ...
# 2351  666049248165822465  2015-11-16 00:24:50 +0000
# 2352  666044226329800704  2015-11-16 00:04:52 +0000
# 2353  666033412701032449  2015-11-15 23:21:54 +0000
# 2354  666029285002620928  2015-11-15 23:05:30 +0000
# 2355  666020888022790149  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 0     This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1     This is Tilly. She's just checking pup on you....                  NaN
# 2     This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3     This is Darla. She commenced a snooze mid meal...                  NaN
# 4     This is Franklin. He would like you to stop ca...                  NaN
# ...                                                 ...                  ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...                  NaN
# 2352  This is a purebred Piers Morgan. Loves to Netf...                  NaN
# 2353  Here is a very happy pup. Big fan of well-main...                  NaN
# 2354  This is a western brown Mitsubishi terrier. Up...                  NaN
# 2355  Here we have a Japanese Irish Setter. Lost eye...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 2351                       NaN                        NaN
# 2352                       NaN                        NaN
# 2353                       NaN                        NaN
# 2354                       NaN                        NaN
# 2355                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator      name doggo floofer pupper puppo
# 0                     10   Phineas  None    None   None  None
# 1                     10     Tilly  None    None   None  None
# 2                     10    Archie  None    None   None  None
# 3                     10     Darla  None    None   None  None
# 4                     10  Franklin  None    None   None  None
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10      None  None    None   None  None
# 2352                  10      None  None    None   None  None
# 2353                  10      None  None    None   None  None
# 2354                  10      None  None    None   None  None
# 2355                  10      None  None    None   None  None
#
# [2356 rows x 15 columns]

# %% [markdown]
# # define
# remove  retweeted_status_id and retweeted_status_user_id and retweeted_status_timestamp

# %%
read_arch_new.drop(["retweeted_status_id","retweeted_status_user_id","retweeted_status_timestamp"],axis=1, inplace =True)

# %%
read_arch_new
# Out:
#                 tweet_id                  timestamp  \
# 0     892420643555336193  2017-08-01 16:23:56 +0000
# 1     892177421306343426  2017-08-01 00:17:27 +0000
# 2     891815181378084864  2017-07-31 00:18:03 +0000
# 3     891689557279858688  2017-07-30 15:58:51 +0000
# 4     891327558926688256  2017-07-29 16:00:24 +0000
# ...                  ...                        ...
# 2351  666049248165822465  2015-11-16 00:24:50 +0000
# 2352  666044226329800704  2015-11-16 00:04:52 +0000
# 2353  666033412701032449  2015-11-15 23:21:54 +0000
# 2354  666029285002620928  2015-11-15 23:05:30 +0000
# 2355  666020888022790149  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 0     This is Phineas. He's a mystical boy. Only eve...
# 1     This is Tilly. She's just checking pup on you....
# 2     This is Archie. He is a rare Norwegian Pouncin...
# 3     This is Darla. She commenced a snooze mid meal...
# 4     This is Franklin. He would like you to stop ca...
# ...                                                 ...
# 2351  Here we have a 1949 1st generation vulpix. Enj...
# 2352  This is a purebred Piers Morgan. Loves to Netf...
# 2353  Here is a very happy pup. Big fan of well-main...
# 2354  This is a western brown Mitsubishi terrier. Up...
# 2355  Here we have a Japanese Irish Setter. Lost eye...
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2351  https://twitter.com/dog_rates/status/666049248...                 5
# 2352  https://twitter.com/dog_rates/status/666044226...                 6
# 2353  https://twitter.com/dog_rates/status/666033412...                 9
# 2354  https://twitter.com/dog_rates/status/666029285...                 7
# 2355  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator      name doggo floofer pupper puppo
# 0                     10   Phineas  None    None   None  None
# 1                     10     Tilly  None    None   None  None
# 2                     10    Archie  None    None   None  None
# 3                     10     Darla  None    None   None  None
# 4                     10  Franklin  None    None   None  None
# ...                  ...       ...   ...     ...    ...   ...
# 2351                  10      None  None    None   None  None
# 2352                  10      None  None    None   None  None
# 2353                  10      None  None    None   None  None
# 2354                  10      None  None    None   None  None
# 2355                  10      None  None    None   None  None
#
# [2356 rows x 12 columns]

# %% [markdown]
# # define
# convert the coulmns timestamp from type object to datatime object.

# %%
#convern the object to date time 
read_arch_new["timestamp"] = pd.to_datetime(read_arch_new["timestamp"])

# %%
read_arch_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2356 non-null   int64
#  1   timestamp           2356 non-null   datetime64[ns, UTC]
#  2   source              2356 non-null   object
#  3   text                2356 non-null   object
#  4   expanded_urls       2297 non-null   object
#  5   rating_numerator    2356 non-null   int64
#  6   rating_denominator  2356 non-null   int64
#  7   name                2356 non-null   object
#  8   doggo               2356 non-null   object
#  9   floofer             2356 non-null   object
#  10  pupper              2356 non-null   object
#  11  puppo               2356 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(3), object(8)
# memory usage: 221.0+ KB

# %% [markdown]
# # define
# make the one variable in new coulmns of type dog

# %%
# i storge the new data about dog in list 
type_dog = []
dog_title = ["pupper","puppo","doggo","floofer"]
y = ["pupper","puppo","doggo","floofer"]
# for loop to read all line in file line by line 
for row in read_arch_new["text"]:
    #make the all word is lower 
    row = row.lower()
    for word in dog_title:
        if word in str(row):
            type_dog.append(y[dog_title.index(word)])
            break
    else:
        type_dog.append("None")
read_arch_new["dog_type"] =type_dog

# %%
read_arch_new["dog_type"].value_counts()
# Out:
# None       1933
# pupper      283
# doggo        93
# puppo        38
# floofer       9
# Name: dog_type, dtype: int64

# %%
# show all column's name only 
read_arch_new.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'expanded_urls',
#        'rating_numerator', 'rating_denominator', 'name', 'doggo', 'floofer',
#        'pupper', 'puppo', 'dog_type'],
#       dtype='object')

# %% [markdown]
# # define
# remove dogoo floofer pupper puppo coulmns

# %%
read_arch_new.drop(["pupper", "puppo", "doggo", "floofer"],axis=1, inplace =True)

# %%
read_arch_new.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'expanded_urls',
#        'rating_numerator', 'rating_denominator', 'name', 'dog_type'],
#       dtype='object')

# %% [markdown]
# # define
# make the three table is one table

# %%
df = read_arch_new.merge(read_tweets_new)

# %%
all_data = df.merge(read_images_new)

# %%
all_data.sample(20)
# Out:
#                 tweet_id                 timestamp  \
# 464   801115127852503040 2016-11-22 17:28:25+00:00
# 829   747219827526344708 2016-06-27 00:07:44+00:00
# 1996  667435689202614272 2015-11-19 20:14:03+00:00
# 313   825876512159186944 2017-01-30 01:21:19+00:00
# 601   779834332596887552 2016-09-25 00:06:08+00:00
# 25    886983233522544640 2017-07-17 16:17:36+00:00
# 47    882045870035918850 2017-07-04 01:18:17+00:00
# 1161  700796979434098688 2016-02-19 21:39:54+00:00
# 278   831315979191906304 2017-02-14 01:35:49+00:00
# 353   819347104292290561 2017-01-12 00:55:47+00:00
# 376   816697700272001025 2017-01-04 17:27:59+00:00
# 229   838916489579200512 2017-03-07 00:57:32+00:00
# 1816  670764103623966721 2015-11-29 00:39:59+00:00
# 286   829501995190984704 2017-02-09 01:27:41+00:00
# 1025  713177543487135744 2016-03-25 01:35:51+00:00
# 1750  671866342182637568 2015-12-02 01:39:53+00:00
# 422   809448704142938112 2016-12-15 17:23:04+00:00
# 1891  669328503091937280 2015-11-25 01:35:25+00:00
# 1332  687312378585812992 2016-01-13 16:36:55+00:00
# 1586  675497103322386432 2015-12-12 02:07:14+00:00
#
#                                                  source  \
# 464   <a href="http://twitter.com/download/iphone" r...
# 829   <a href="http://twitter.com/download/iphone" r...
# 1996  <a href="http://twitter.com/download/iphone" r...
# 313   <a href="http://twitter.com/download/iphone" r...
# 601   <a href="http://twitter.com/download/iphone" r...
# 25    <a href="http://twitter.com/download/iphone" r...
# 47    <a href="http://twitter.com/download/iphone" r...
# 1161  <a href="http://twitter.com/download/iphone" r...
# 278   <a href="http://twitter.com" rel="nofollow">Tw...
# 353   <a href="http://twitter.com/download/iphone" r...
# 376   <a href="http://twitter.com/download/iphone" r...
# 229   <a href="http://twitter.com/download/iphone" r...
# 1816  <a href="http://twitter.com/download/iphone" r...
# 286   <a href="http://twitter.com/download/iphone" r...
# 1025  <a href="http://twitter.com/download/iphone" r...
# 1750  <a href="http://twitter.com/download/iphone" r...
# 422   <a href="http://twitter.com/download/iphone" r...
# 1891  <a href="http://twitter.com/download/iphone" r...
# 1332  <a href="http://twitter.com/download/iphone" r...
# 1586  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 464   This is Bones. He's being haunted by another d...
# 829   This is Atticus. He's remaining calm but his c...
# 1996            Ermergerd 12/10 https://t.co/PQni2sjPsm
# 313   This is Mo. No one will push him around in the...
# 601   This is Scout. He really wants to kiss himself...
# 25    This is Maya. She's very shy. Rarely leaves he...
# 47    This is Koko. Her owner, inspired by Barney, r...
# 1161  This is Daniel. He's a neat pup. Exotic af. Cu...
# 278   I couldn't make it to the #WKCDogShow BUT I ha...
# 353   Say hello to Anna and Elsa. They fall asleep i...
# 376   This is Binky. She appears to be rather h*ckin...
# 229   RT @KibaDva: I collected all the good dogs!! 1...
# 1816  Meet Vincent. He's a wild Adderall Cayenne. Sh...
# 286   This is Leo. He was a skater pup. She said see...
# 1025  This is Lance. Lance doesn't give a shit. 10/1...
# 1750  Meet Dylan. He can use a fork but clearly can'...
# 422   I call this one "A Blep by the Sea" 12/10 http...
# 1891  This is Kirk. He just saw a bacon wrapped tenn...
# 1332  "You got any games on your phone" 7/10 for inv...
# 1586  Meet Reggie. He's going for the world record. ...
#
#                                           expanded_urls  rating_numerator  \
# 464   https://twitter.com/dog_rates/status/801115127...                12
# 829   https://twitter.com/dog_rates/status/747219827...                11
# 1996  https://twitter.com/dog_rates/status/667435689...                12
# 313   https://twitter.com/dog_rates/status/825876512...                11
# 601   https://twitter.com/dog_rates/status/779834332...                11
# 25    https://twitter.com/dog_rates/status/886983233...                13
# 47    https://twitter.com/dog_rates/status/882045870...                13
# 1161  https://twitter.com/dog_rates/status/700796979...                 7
# 278   https://twitter.com/dog_rates/status/831315979...                13
# 353   https://twitter.com/dog_rates/status/819347104...                12
# 376   https://twitter.com/dog_rates/status/816697700...                12
# 229   https://twitter.com/KibaDva/status/83890598062...                15
# 1816  https://twitter.com/dog_rates/status/670764103...                10
# 286   https://twitter.com/dog_rates/status/829501995...                12
# 1025  https://twitter.com/dog_rates/status/713177543...                10
# 1750  https://twitter.com/dog_rates/status/671866342...                10
# 422   https://twitter.com/dog_rates/status/809448704...                12
# 1891  https://twitter.com/dog_rates/status/669328503...                12
# 1332  https://twitter.com/dog_rates/status/687312378...                 7
# 1586  https://twitter.com/dog_rates/status/675497103...                11
#
#       rating_denominator     name dog_type  retweet_count  favorite_count  \
# 464                   10    Bones   pupper           2429            8992
# 829                   10  Atticus     None           1791            5792
# 1996                  10     None     None             89             326
# 313                   10       Mo     None           2146           11525
# 601                   10    Scout     None           8237           21252
# 25                    10     Maya     None           8084           35859
# 47                    10     Koko     None           5203           29900
# 1161                  10   Daniel     None           1085            2669
# 278                   10     None   pupper           1264            7117
# 353                   10     Anna     None           1383            8008
# 376                   10    Binky     None           2545           10905
# 229                   10     None     None             38               0
# 1816                  10  Vincent     None            466            1154
# 286                   10      Leo     None          12224           34913
# 1025                  10    Lance     None           3183            7854
# 1750                  10    Dylan     None            548            1191
# 422                   10     None     None           1696            7727
# 1891                  10     Kirk     None            452            1081
# 1332                  10     None   pupper           2146            4777
# 1586                  10   Reggie     None           1443            3397
#
#                                               jpg_url  img_num  \
# 464   https://pbs.twimg.com/media/Cx4h7zHUsAAqaJd.jpg        1
# 829   https://pbs.twimg.com/media/Cl6odlVWQAIy5uk.jpg        2
# 1996  https://pbs.twimg.com/media/CUM1OHCW4AEgGSi.jpg        1
# 313   https://pbs.twimg.com/media/C3YaSnQWAAILgz0.jpg        1
# 601   https://pbs.twimg.com/media/CtKHLuCWYAA2TTs.jpg        1
# 25    https://pbs.twimg.com/media/DE8yicJW0AAAvBJ.jpg        2
# 47    https://pbs.twimg.com/media/DD2oCl2WAAEI_4a.jpg        1
# 1161  https://pbs.twimg.com/media/Cbm7IeUXIAA6Lc-.jpg        1
# 278   https://pbs.twimg.com/media/C4lst0bXAAE6MP8.jpg        4
# 353   https://pbs.twimg.com/media/C17n1nrWQAIErU3.jpg        3
# 376   https://pbs.twimg.com/media/C1V-K63UAAEUHqw.jpg        1
# 229   https://pbs.twimg.com/media/C6RkiQZUsAAM4R4.jpg        2
# 1816  https://pbs.twimg.com/media/CU8IY0pWIAA2AJ-.jpg        1
# 286   https://pbs.twimg.com/media/C4L7p19W8AA3Fs_.jpg        1
# 1025  https://pbs.twimg.com/media/CeW3MWMWQAEOMbq.jpg        1
# 1750  https://pbs.twimg.com/media/CVLy3zFWoAA93qJ.jpg        1
# 422   https://pbs.twimg.com/media/Czu9RiwVEAA_Okk.jpg        1
# 1891  https://pbs.twimg.com/media/CUnuuLEWEAAlKjN.jpg        1
# 1332  https://pbs.twimg.com/media/CYnS9VWW8AAeR8m.jpg        1
# 1586  https://pbs.twimg.com/media/CV_ZAhcUkAUeKtZ.jpg        1
#
#                               p1   p1_conf  p1_dog  \
# 464                    dalmatian  0.823356    True
# 829            Shetland sheepdog  0.548018    True
# 1996                  Rottweiler  0.999091    True
# 313                shopping cart  0.995941   False
# 601             golden retriever  0.993830    True
# 25                     Chihuahua  0.793469    True
# 47                      web site  0.949591   False
# 1161                 tailed frog  0.652712   False
# 278                       briard  0.982755    True
# 353                   Rottweiler  0.909106    True
# 376                    Chihuahua  0.756992    True
# 229                     web site  0.993651   False
# 1816             Norfolk terrier  0.172850    True
# 286               French bulldog  0.950851    True
# 1025                     whippet  0.734244    True
# 1750          Labrador retriever  0.875614    True
# 422   Greater Swiss Mountain dog  0.375415    True
# 1891              Siberian husky  0.424202    True
# 1332                   seat belt  0.703561   False
# 1586                      vizsla  0.519589    True
#
#                                p2   p2_conf  p2_dog                       p3  \
# 464                English setter  0.094602    True                 bluetick
# 829                        marmot  0.165503   False                   collie
# 1996           miniature pinscher  0.000450    True  black-and-tan coonhound
# 313               shopping basket  0.004057   False                mousetrap
# 601                cocker spaniel  0.003143    True           Great Pyrenees
# 25                    toy terrier  0.143528    True               can opener
# 47                          dhole  0.017326   False         golden retriever
# 1161                    tree frog  0.280212   False                 bullfrog
# 278   soft-coated wheaten terrier  0.009084    True     Bouvier des Flandres
# 353       black-and-tan coonhound  0.044120    True                 Doberman
# 376                    Pomeranian  0.052850    True              Maltese dog
# 229                       monitor  0.001406   False                 envelope
# 1816             golden retriever  0.072702    True               television
# 286                      Pekinese  0.015200    True                      pug
# 1025                      basenji  0.025948    True               Great Dane
# 1750                    Chihuahua  0.032182    True         golden retriever
# 422                      Cardigan  0.134317    True         English springer
# 1891                   Eskimo dog  0.237660    True                 malamute
# 1332                   Great Dane  0.139909    True               Weimaraner
# 1586           miniature pinscher  0.064771    True      Rhodesian ridgeback
#
#            p3_conf  p3_dog
# 464   2.195340e-02    True
# 829   4.300260e-02    True
# 1996  1.571400e-04    True
# 313   8.832830e-07   False
# 601   9.174140e-04    True
# 25    3.225290e-02   False
# 47    6.940630e-03    True
# 1161  4.017750e-02   False
# 278   4.692800e-03    True
# 353   3.183490e-02    True
# 376   4.760780e-02    True
# 229   1.093090e-03   False
# 1816  3.749420e-02   False
# 286   1.109360e-02    True
# 1025  2.587430e-02    True
# 1750  1.723250e-02    True
# 422   7.369710e-02    True
# 1891  5.257170e-02    True
# 1332  2.111250e-02    True
# 1586  6.149130e-02    True

# %% [markdown]
# # define
# removing the tweets without images

# %%
all_data = all_data[pd.notnull(all_data["jpg_url"])]

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2073 entries, 0 to 2072
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2073 non-null   int64
#  1   timestamp           2073 non-null   datetime64[ns, UTC]
#  2   source              2073 non-null   object
#  3   text                2073 non-null   object
#  4   expanded_urls       2073 non-null   object
#  5   rating_numerator    2073 non-null   int64
#  6   rating_denominator  2073 non-null   int64
#  7   name                2073 non-null   object
#  8   dog_type            2073 non-null   object
#  9   retweet_count       2073 non-null   int64
#  10  favorite_count      2073 non-null   int64
#  11  jpg_url             2073 non-null   object
#  12  img_num             2073 non-null   int64
#  13  p1                  2073 non-null   object
#  14  p1_conf             2073 non-null   float64
#  15  p1_dog              2073 non-null   bool
#  16  p2                  2073 non-null   object
#  17  p2_conf             2073 non-null   float64
#  18  p2_dog              2073 non-null   bool
#  19  p3                  2073 non-null   object
#  20  p3_conf             2073 non-null   float64
#  21  p3_dog              2073 non-null   bool
# dtypes: bool(3), datetime64[ns, UTC](1), float64(3), int64(6), object(9)
# memory usage: 330.0+ KB

# %%
all_data
# Out:
#                 tweet_id                 timestamp  \
# 0     892420643555336193 2017-08-01 16:23:56+00:00
# 1     892177421306343426 2017-08-01 00:17:27+00:00
# 2     891815181378084864 2017-07-31 00:18:03+00:00
# 3     891689557279858688 2017-07-30 15:58:51+00:00
# 4     891327558926688256 2017-07-29 16:00:24+00:00
# ...                  ...                       ...
# 2068  666049248165822465 2015-11-16 00:24:50+00:00
# 2069  666044226329800704 2015-11-16 00:04:52+00:00
# 2070  666033412701032449 2015-11-15 23:21:54+00:00
# 2071  666029285002620928 2015-11-15 23:05:30+00:00
# 2072  666020888022790149 2015-11-15 22:32:08+00:00
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/iphone" r...
# 2     <a href="http://twitter.com/download/iphone" r...
# 3     <a href="http://twitter.com/download/iphone" r...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 2068  <a href="http://twitter.com/download/iphone" r...
# 2069  <a href="http://twitter.com/download/iphone" r...
# 2070  <a href="http://twitter.com/download/iphone" r...
# 2071  <a href="http://twitter.com/download/iphone" r...
# 2072  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  \
# 0     This is Phineas. He's a mystical boy. Only eve...
# 1     This is Tilly. She's just checking pup on you....
# 2     This is Archie. He is a rare Norwegian Pouncin...
# 3     This is Darla. She commenced a snooze mid meal...
# 4     This is Franklin. He would like you to stop ca...
# ...                                                 ...
# 2068  Here we have a 1949 1st generation vulpix. Enj...
# 2069  This is a purebred Piers Morgan. Loves to Netf...
# 2070  Here is a very happy pup. Big fan of well-main...
# 2071  This is a western brown Mitsubishi terrier. Up...
# 2072  Here we have a Japanese Irish Setter. Lost eye...
#
#                                           expanded_urls  rating_numerator  \
# 0     https://twitter.com/dog_rates/status/892420643...                13
# 1     https://twitter.com/dog_rates/status/892177421...                13
# 2     https://twitter.com/dog_rates/status/891815181...                12
# 3     https://twitter.com/dog_rates/status/891689557...                13
# 4     https://twitter.com/dog_rates/status/891327558...                12
# ...                                                 ...               ...
# 2068  https://twitter.com/dog_rates/status/666049248...                 5
# 2069  https://twitter.com/dog_rates/status/666044226...                 6
# 2070  https://twitter.com/dog_rates/status/666033412...                 9
# 2071  https://twitter.com/dog_rates/status/666029285...                 7
# 2072  https://twitter.com/dog_rates/status/666020888...                 8
#
#       rating_denominator      name dog_type  retweet_count  favorite_count  \
# 0                     10   Phineas     None           8853           39467
# 1                     10     Tilly     None           6514           33819
# 2                     10    Archie     None           4328           25461
# 3                     10     Darla     None           8964           42908
# 4                     10  Franklin     None           9774           41048
# ...                  ...       ...      ...            ...             ...
# 2068                  10      None     None             41             111
# 2069                  10      None     None            147             311
# 2070                  10      None     None             47             128
# 2071                  10      None     None             48             132
# 2072                  10      None     None            532            2535
#
#                                               jpg_url  img_num  \
# 0     https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg        1
# 1     https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg        1
# 2     https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg        1
# 3     https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg        1
# 4     https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg        2
# ...                                               ...      ...
# 2068  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg        1
# 2069  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg        1
# 2070  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg        1
# 2071  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg        1
# 2072  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg        1
#
#                           p1   p1_conf  p1_dog                  p2   p2_conf  \
# 0                     orange  0.097049   False               bagel  0.085851
# 1                  Chihuahua  0.323581    True            Pekinese  0.090647
# 2                  Chihuahua  0.716012    True            malamute  0.078253
# 3                paper towel  0.170278   False  Labrador retriever  0.168086
# 4                     basset  0.555712    True    English springer  0.225770
# ...                      ...       ...     ...                 ...       ...
# 2068      miniature pinscher  0.560311    True          Rottweiler  0.243682
# 2069     Rhodesian ridgeback  0.408143    True             redbone  0.360687
# 2070         German shepherd  0.596461    True            malinois  0.138584
# 2071                 redbone  0.506826    True  miniature pinscher  0.074192
# 2072  Welsh springer spaniel  0.465074    True              collie  0.156665
#
#       p2_dog                           p3   p3_conf  p3_dog
# 0      False                       banana  0.076110   False
# 1       True                     papillon  0.068957    True
# 2       True                       kelpie  0.031379    True
# 3       True                      spatula  0.040836   False
# 4       True  German short-haired pointer  0.175219    True
# ...      ...                          ...       ...     ...
# 2068    True                     Doberman  0.154629    True
# 2069    True           miniature pinscher  0.222752    True
# 2070    True                   bloodhound  0.116197    True
# 2071    True          Rhodesian ridgeback  0.072010    True
# 2072    True            Shetland sheepdog  0.061428    True
#
# [2073 rows x 22 columns]

# %% [markdown]
# # Storing data

# %%
all_data.to_csv("twitter_archive_master_new.csv",encoding="Utf-8",index=False)

# %%
all_data_new=pd.read_csv("twitter_archive_master_new.csv")

# %%
all_data_new.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56+00:00
# 1  892177421306343426  2017-08-01 00:17:27+00:00
# 2  891815181378084864  2017-07-31 00:18:03+00:00
# 3  891689557279858688  2017-07-30 15:58:51+00:00
# 4  891327558926688256  2017-07-29 16:00:24+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name dog_type  retweet_count  favorite_count  \
# 0                  10   Phineas     None           8853           39467
# 1                  10     Tilly     None           6514           33819
# 2                  10    Archie     None           4328           25461
# 3                  10     Darla     None           8964           42908
# 4                  10  Franklin     None           9774           41048
#
#                                            jpg_url  img_num           p1  \
# 0  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg        1       orange
# 1  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg        1    Chihuahua
# 2  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg        1    Chihuahua
# 3  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg        1  paper towel
# 4  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg        2       basset
#
#     p1_conf  p1_dog                  p2   p2_conf  p2_dog  \
# 0  0.097049   False               bagel  0.085851   False
# 1  0.323581    True            Pekinese  0.090647    True
# 2  0.716012    True            malamute  0.078253    True
# 3  0.170278   False  Labrador retriever  0.168086    True
# 4  0.555712    True    English springer  0.225770    True
#
#                             p3   p3_conf  p3_dog
# 0                       banana  0.076110   False
# 1                     papillon  0.068957    True
# 2                       kelpie  0.031379    True
# 3                      spatula  0.040836   False
# 4  German short-haired pointer  0.175219    True

# %%
all_data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2073 non-null   int64
#  1   timestamp           2073 non-null   object
#  2   source              2073 non-null   object
#  3   text                2073 non-null   object
#  4   expanded_urls       2073 non-null   object
#  5   rating_numerator    2073 non-null   int64
#  6   rating_denominator  2073 non-null   int64
#  7   name                2073 non-null   object
#  8   dog_type            2073 non-null   object
#  9   retweet_count       2073 non-null   int64
#  10  favorite_count      2073 non-null   int64
#  11  jpg_url             2073 non-null   object
#  12  img_num             2073 non-null   int64
#  13  p1                  2073 non-null   object
#  14  p1_conf             2073 non-null   float64
#  15  p1_dog              2073 non-null   bool
#  16  p2                  2073 non-null   object
#  17  p2_conf             2073 non-null   float64
#  18  p2_dog              2073 non-null   bool
#  19  p3                  2073 non-null   object
#  20  p3_conf             2073 non-null   float64
#  21  p3_dog              2073 non-null   bool
# dtypes: bool(3), float64(3), int64(6), object(10)
# memory usage: 313.9+ KB

# %% [markdown]
# # Analysis

# %% [markdown]
# we will look rating dog in pie

# %%
from matplotlib import pyplot as plt
import seaborn as sns
plt.style.use("dark_background")
data = all_data_new["rating_numerator"].value_counts()
x = data.index
y = data.values
fig, ax = plt.subplots(figsize=(12,6))
g =sns.barplot(x,y, palette="Blues",ax=ax)
ax.set(xlabel="Ratings",ylabel="frequency", title= "Rating Frequency")
plt.show()
# Out:
# /home/eslam/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# this graph show us most rating for dog is 12 and some pepole don't like its dog because he give its little rating

# %%
all_data_new.plot(kind="scatter", x="favorite_count",y= "retweet_count",alpha= 0.5, figsize=(7,7) , color="blue")
plt.xlabel("favorites")
plt.ylabel("retweets")
plt.title("favorites and retweets")
# Out:
# Text(0.5, 1.0, 'favorites and retweets')

# %% [markdown]
# more retweet mean more favourite

# %%
x = all_data_new["dog_type"]
y = all_data_new["retweet_count"]
fig, ax = plt.subplots(figsize=(12,6))
g =sns.barplot(x,y, palette="Blues",ax=ax)
ax.set(xlabel="Dog type",ylabel="Retweet", title= "Number of Rtweet each dog type ")
plt.show();
# Out:
# /home/eslam/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# most pepole have the ability to retweet when they see doggo and puppo

# %%
x = all_data_new["dog_type"]
y = all_data_new["favorite_count"]
fig, ax = plt.subplots(figsize=(12,6))
g =sns.barplot(x,y, palette="Blues",ax=ax)
ax.set(xlabel="Dog type",ylabel="Favorite", title= "Number of favorite each dog type ")
plt.show();
# Out:
# /home/eslam/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# most people interact with favourite when see doggo and puppo
